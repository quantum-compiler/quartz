# %%
import matplotlib.pyplot as plt
from qiskit import QuantumCircuit, transpile, qasm
from qiskit.test.mock import FakeBoeblingen
backend = FakeBoeblingen()
# Out:
# /tmp/ipykernel_39774/4219961241.py:3: DeprecationWarning: The module 'qiskit.test.mock' is deprecated since Qiskit Terra 0.21.0, and will be removed 3 months or more later. Instead, you should import the desired object directly 'qiskit.providers.fake_provider'.
#   from qiskit.test.mock import FakeBoeblingen

# %%
circ = QuantumCircuit.from_qasm_file("../circs/ibm_extra_circs/ghz_nativegates_ibm_tket_8.qasm")
circ.draw(output='mpl')

# %%
circ = transpile(circ, basis_gates=["cx", "rz", "sx", "x"], optimization_level=3)
circ.draw(output='mpl')

# %%
circ = QuantumCircuit.from_qasm_file("../circs/ibm_extra_circs/twolocalrandom_nativegates_ibm_tket_8.qasm")
circ.draw(output='mpl')

# %%
circ = transpile(circ, basis_gates=["cx", "rz", "sx", "x"], optimization_level=3)
circ.draw(output='mpl')

# %%
circ = QuantumCircuit.from_qasm_file("../circs/ibm_extra_circs/vqe_nativegates_ibm_tket_8.qasm")
circ.draw(output='mpl')

# %%
circ = QuantumCircuit(1)
circ.h(0)
circ = transpile(circ, basis_gates=['rz', 'sx'])
circ.draw(output='mpl')

# %%
barenco_tof_3_circ = QuantumCircuit.from_qasm_file('../circuit/nam-circuits/qasm_files/barenco_tof_3_before.qasm')
barenco_tof_3_circ.draw(output='mpl')

# %%
optimized_circ = transpile(barenco_tof_3_circ, basis_gates=['rz', 'rx', 'cz'], optimization_level=3)
print(optimized_circ.count_ops())
print(optimized_circ.depth())
optimized_circ.draw(output='mpl')
# Out:
# OrderedDict([('rx', 40), ('cz', 24), ('rz', 21)])
# 51
